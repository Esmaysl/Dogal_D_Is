# %% [markdown]
# <a href="https://colab.research.google.com/github/Esmaysl/Dogal_D_Is/blob/main/Colaboratory'ye_Ho%C5%9F_Geldiniz_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Fotoğrafı gri tonlamalı olarak yükle
image_path = "/content/indir.jfif"  # Kendi dosya yolunu kullan
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Canny kenar algılama uygula
edges = cv2.Canny(image, threshold1=100, threshold2=200)

# Sonuçları görselleştir
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap="gray")
plt.title("Orijinal Görüntü")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(edges, cmap="gray")
plt.title("Kenar Algılama (Canny)")
plt.axis("off")

plt.show()
